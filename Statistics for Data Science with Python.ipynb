# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
boston_df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
boston_df.info()
boston_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  LSTAT       506 non-null    float64
#  13  MEDV        506 non-null    float64
#  14  Age_Group   506 non-null    object
# dtypes: float64(13), int64(1), object(1)
# memory usage: 59.4+ KB
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# ...

# %% [markdown]
# # Question 1

# %% [markdown]
# **For the "Median value of owner-occupied homes" provide a boxplot**

# %%
sns.set(style="whitegrid")
ax = sns.boxplot(x ='MEDV', data = boston_df)
ax.set( xlabel = "MEDV ")
ax.set_title("Median value of owner-occupied homes in $1000's")
plt.show()

# %% [markdown]
# # Question 2

# %% [markdown]
# **Provide a  bar plot for the Charles river variable**

# %%
data = boston_df['CHAS'].value_counts()
ax2 = sns.barplot(x = data.index, y = data.values)
ax2.set(xlabel = "CHAS", ylabel = "Count")
ax2.set_title("Homes near Charles River (1 if tract bounds river; 0 otherwise)")
plt.show()

# %% [markdown]
# # Question 3

# %% [markdown]
# **Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)**

# %%
boston_df.loc[(boston_df['AGE'] <= 35), 'Age_Group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'Age_Group'] = 'between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'Age_Group'] = '70 years and older'

# %%
ax3 = sns.boxplot(x = 'MEDV', y = 'Age_Group', data = boston_df)
ax3.set_title("Median value of owner-occupied homes per Age Group")
# Out:
# Text(0.5, 1.0, 'Median value of owner-occupied homes per Age Group')

# %% [markdown]
# # Question 4

# %% [markdown]
# **Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?**

# %%
ax4 = sns.scatterplot(y = 'NOX', x = 'INDUS', data = boston_df)
ax4.set_title("Nitric oxide concentration and proportion of non-retail business acres per town")
# Out:
# Text(0.5, 1.0, 'Nitric oxide concentration and proportion of non-retail business acres per town')

# %% [markdown]
# A strong relationship is observed between low Nitric oxide concetrations and low proportion of non-retail business acres per town.

# %% [markdown]
# # Question 5

# %% [markdown]
# **Create a histogram for the pupil to teacher ratio variable**

# %%
ax5 = sns.countplot(x = 'PTRATIO', data = boston_df)
ax5.set_title("Pupil to teacher ratio per town")
# Out:
# Text(0.5, 1.0, 'Pupil to teacher ratio per town')

# %% [markdown]
# # Question 6

# %% [markdown]
# **Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)**
#
# Null Hypothesis -- There is NO significant difference in median value between houses bounded and not bounded by the Charles River
#
# Alternative Hypothesis -- There is a significant difference in median value between houses bounded and not bounded by the Charles River

# %%
import scipy.stats
scipy.stats.ttest_ind(boston_df[boston_df['CHAS'] == 0]['MEDV'], 
                      boston_df[boston_df['CHAS'] == 1]['MEDV'], equal_var = True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# As the above p-value is less than 0.05, we reject the Null Hypothesis.
#
# This means there is no statistically significant difference in median value between houses near the Charles River and houses that are not near.

# %% [markdown]
# # Question 7

# %% [markdown]
# **Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)**

# %% [markdown]
# Null Hypothesis -- There is NO significant difference in Median value of houses (MEDV) for each proportion of owner occupied units built prior to 1940
#
# Alternative Hypothesis -- There is a significant difference in Median value of houses (MEDV) for each proportion of owner occupied units built prior to 1940

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# As the above p-value is less than 0.05, we reject the Null Hypothesis
#
# This means there is a statistically significant difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940

# %% [markdown]
# # Question 8

# %% [markdown]
# **Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)**

# %% [markdown]
# Null Hypothesis -- There is NO significant correlation between Nitric oxide concentrations and proportion of non-retail business acres per town
#
# Alternate Hypothesis -- There is a significant correlation between Nitric oxide concentrations and proportion of non-retail business acres per town

# %%
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
# Out:
# PearsonRResult(statistic=0.7636514469209151, pvalue=7.913361061239527e-98)

# %% [markdown]
# As the above Pearson coefficient is 0.76365 and p-value is less than 0.05, we reject the Null Hypothesis and assert the Alternate Hypothesis that there is a correlation.

# %% [markdown]
# # Question 9

# %% [markdown]
# **What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)**

# %%
x = boston_df['DIS']
y = boston_df['MEDV']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
prediction = model.predict(x)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           1.21e-08
# Time:                        04:37:36   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [markdown]
# The impact of an additional weighted distance to the five Boston employment centres is represented by the DIS coefficient of 1.0916, which translates to an estimated increase of 1.0916 ($10,916) to the median value of owner occupied homes, in the dependant variable MEDV.
